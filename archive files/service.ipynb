# %%
print('hello')
# Out:
# hello

# %%
import os
from openai import OpenAI

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))  # 또는 직접 API 키 입력

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "항상 한국어로 짧고 간결하게 대답해 주세요."},
        {"role": "user", "content": "식약처에 내가 만든 음식이 안전하다고 보여주고 싶은데, 전화 어디로 걸어야 해? 전화번호"}
    ]
)

print(response.choices[0].message.content)
# Out:
# 식약처에 문의하려면 1393으로 전화하세요.

# %%
import os
from openai import OpenAI

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))  # 또는 직접 API 키 입력

response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "항상 한국어로 짧고 간결하게 대답해 주세요."},
        {"role": "user", "content": "식약처에 내가 만든 음식이 안전하다고 보여주고 싶은데, 전화 어디로 걸어야 해? 전화번호"}
    ]
)

print(response.choices[0].message.content)
# Out:
# 식품의약품안전처 고객지원센터로 전화하시면 됩니다. 번호는 1577-1255입니다.

# %%
import os
from openai import OpenAI

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))  # 또는 직접 API 키 입력

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "항상 한국어로 짧고 간결하게 대답해 주세요."},
        {"role": "user", "content": "식약처에 내가 만든 음식이 안전하다고 보여주고 싶은데, 전화 어디로 걸어야 해? 전화번호"}
    ]
)

print(response.choices[0].message.content)
# Out:
# 식약처 고객센터에 전화하시면 됩니다. 전화번호는 1577-1255입니다.

# %%
import os
from openai import OpenAI

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))  # 또는 직접 API 키 입력

response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "항상 한국어로 짧고 간결하게 대답해 주세요."},
        {"role": "user", "content": "식약처에 내가 만든 음식이 안전하다고 보여주고 싶은데, 전화 어디로 걸어야 해? 전화번호"}
    ]
)

print(response.choices[0].message.content)
# Out:
# 식약처 대표전화 043-719-2114로 문의하세요.

# %%
import pandas as pd

# call_numbers.xlsx 파일을 DataFrame으로 불러오기
df = pd.read_excel("call_numbers.xlsx")

# 데이터 확인
df.head(50)  # Jupyter에서는 이렇게 하면 표로 출력됨
# Out:
#           부처명          대표전화                        홈페이지  비고
# 0   개인정보보호위원회     1833-6972      https://www.pipc.go.kr NaN
# 1         경찰청           182    https://www.police.go.kr NaN
# 2       고용노동부          1350      https://www.moel.go.kr NaN
# 3     공정거래위원회     1670-0007       https://www.ftc.go.kr NaN
# 4          공통           110          https://www.gov.kr NaN
# 5   과학기술정보통신부  044-202-2114      https://www.msit.go.kr NaN
# 6         관세청           125   https://www.customs.go.kr NaN
# 7         교육부  044-203-6118       https://www.moe.go.kr NaN
# 8       국가보훈부     1577-0606      https://www.mpva.go.kr NaN
# 9       국가유산청  042-481-4740  https://www.heritage.go.kr NaN
# 10        국방부     1577-9090       https://www.mnd.go.kr NaN
# 11        국세청           126       https://www.nts.go.kr NaN
# 12      국토교통부     1599-0001     https://www.molit.go.kr NaN
# 13      금융위원회          1332       https://www.fsc.go.kr NaN
# 14        기상청           131       https://www.kma.go.kr NaN
# 15      기획재정부  044-215-2114      https://www.moef.go.kr NaN
# 16    농림축산식품부  044-201-1001     https://www.mafra.go.kr NaN
# 17      농촌진흥청  063-238-1000       https://www.rda.go.kr NaN
# 18       대검찰청          1301       https://www.spo.go.kr NaN
# 19        대법원  02-3480-1100    https://www.scourt.go.kr NaN
# 20    문화체육관광부  044-203-2000      https://www.mcst.go.kr NaN
# 21    방송통신위원회          1335       https://www.kcc.go.kr NaN
# 22      방위사업청  02-2079-6114      https://www.dapa.go.kr NaN
# 23        법무부  02-2110-3114       https://www.moj.go.kr NaN
# 24        병무청     1588-9090       https://www.mma.go.kr NaN
# 25      보건복지부           129      https://www.mohw.go.kr NaN
# 26        산림청  042-481-4114    https://www.forest.go.kr NaN
# 27    산업통상자원부  044-203-2114     https://www.motie.go.kr NaN
# 28        소방청  044-205-7442       https://www.nfa.go.kr NaN
# 29   식품의약품안전처     1577-1255      https://www.mfds.go.kr NaN
# 30      여성가족부  02-2100-6000     https://www.mogef.go.kr NaN
# 31        외교부  02-2100-2114      https://www.mofa.go.kr NaN
# 32      우주항공청            --      https://www.kari.re.kr NaN
# 33   원자력안전위원회   02-397-7200      https://www.nssc.go.kr NaN
# 34      인사혁신처  044-201-8000       https://www.mpm.go.kr NaN
# 35      재외동포청  02-3415-0114      https://www.korean.net NaN
# 36        조달청     1588-0800       https://www.pps.go.kr NaN
# 37    중소벤처기업부          1357       https://www.mss.go.kr NaN
# 38      질병관리청          1339      https://www.kdca.go.kr NaN
# 39        통계청  042-481-2114        https://kostat.go.kr NaN
# 40        통일부     1577-1365  https://www.unikorea.go.kr NaN
# 41        특허청     1544-8080      https://www.kipo.go.kr NaN
# 42      해양경찰청  032-835-2114       https://www.kcg.go.kr NaN
# 43      해양수산부  044-200-6114       https://www.mof.go.kr NaN
# 44      행정안전부  02-2100-3399      https://www.mois.go.kr NaN
# 45        환경부  044-201-6000        https://www.me.go.kr NaN

# %%
import os
from openai import OpenAI

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))  # 또는 직접 API 키 입력

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "항상 한국어로 짧고 간결하게 대답해 주세요."},
        {"role": "user", "content": "어제 강남역 앞 도로에 구멍이 생겼는데 어떻게 해요?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# 관할 구청이나 도로 관리 부서에 신고하세요.
