# %%
from keybert import KeyBERT

kw_model = KeyBERT()

doc = "자동차 변경등록 신청을 하려는데, 이전 주소지에서 발급받아야 할 서류가 있다면 어떤 것이 있는지 알고 싶습니다. 이사 후에 어떻게 처리해야 할지 걱정입니다."
keywords = kw_model.extract_keywords(doc, top_n=5)

print(keywords)
# Out:
# [('걱정입니다', 0.7845), ('하려는데', 0.625), ('신청을', 0.5457), ('자동차', 0.5455), ('주소지에서', 0.538)]

# %%
# !pip install keybert
# Out:
# Collecting keybert
#   Downloading keybert-0.9.0-py3-none-any.whl.metadata (15 kB)
# Collecting numpy>=1.18.5 (from keybert)
#   Using cached numpy-2.2.6-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting rich>=10.4.0 (from keybert)
#   Downloading rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting scikit-learn>=0.22.2 (from keybert)
#   Using cached scikit_learn-1.6.1-cp313-cp313-macosx_12_0_arm64.whl.metadata (31 kB)
# Collecting sentence-transformers>=0.3.8 (from keybert)
#   Using cached sentence_transformers-4.1.0-py3-none-any.whl.metadata (13 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.4.0->keybert)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.13/site-packages (from rich>=10.4.0->keybert) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting scipy>=1.6.0 (from scikit-learn>=0.22.2->keybert)
#   Using cached scipy-1.15.3-cp313-cp313-macosx_14_0_arm64.whl.metadata (61 kB)
# Collecting joblib>=1.2.0 (from scikit-learn>=0.22.2->keybert)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=0.22.2->keybert)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers>=0.3.8->keybert)
#   Downloading transformers-4.52.3-py3-none-any.whl.metadata (40 kB)
# Collecting tqdm (from sentence-transformers>=0.3.8->keybert)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting torch>=1.11.0 (from sentence-transformers>=0.3.8->keybert)
#   Using cached torch-2.7.0-cp313-none-macosx_11_0_arm64.whl.metadata (29 kB)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers>=0.3.8->keybert)
#   Downloading huggingface_hub-0.32.2-py3-none-any.whl.metadata (14 kB)
# Collecting Pillow (from sentence-transformers>=0.3.8->keybert)
#   Using cached pillow-11.2.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.9 kB)
# Collecting typing_extensions>=4.5.0 (from sentence-transformers>=0.3.8->keybert)
#   Using cached typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting filelock (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert)
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.13/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (25.0)
# Collecting pyyaml>=5.1 (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert)
#   Using cached PyYAML-6.0.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting regex!=2019.12.17 (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert)
#   Using cached regex-2024.11.6-cp313-cp313-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting requests (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert)
#   Using cached tokenizers-0.21.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.4.3 (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert)
#   Using cached safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert)
#   Downloading fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# Collecting hf-xet<2.0.0,>=1.1.2 (from huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert)
#   Downloading hf_xet-1.1.2-cp37-abi3-macosx_11_0_arm64.whl.metadata (879 bytes)
# Collecting setuptools (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Using cached MarkupSafe-3.0.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert)
#   Using cached charset_normalizer-3.4.2-cp313-cp313-macosx_10_13_universal2.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert)
#   Using cached urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert)
#   Using cached certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Downloading keybert-0.9.0-py3-none-any.whl (41 kB)
# Using cached numpy-2.2.6-cp313-cp313-macosx_14_0_arm64.whl (5.1 MB)
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached scikit_learn-1.6.1-cp313-cp313-macosx_12_0_arm64.whl (11.1 MB)
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Using cached scipy-1.15.3-cp313-cp313-macosx_14_0_arm64.whl (22.4 MB)
# Using cached sentence_transformers-4.1.0-py3-none-any.whl (345 kB)
# Downloading transformers-4.52.3-py3-none-any.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 22.8 MB/s eta 0:00:00 0:00:01
# Downloading huggingface_hub-0.32.2-py3-none-any.whl (509 kB)
# Downloading hf_xet-1.1.2-cp37-abi3-macosx_11_0_arm64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 10.2 MB/s eta 0:00:00a 0:00:01
# Using cached tokenizers-0.21.1-cp39-abi3-macosx_11_0_arm64.whl (2.7 MB)
# Downloading fsspec-2025.5.1-py3-none-any.whl (199 kB)
# Using cached PyYAML-6.0.2-cp313-cp313-macosx_11_0_arm64.whl (171 kB)
# Using cached regex-2024.11.6-cp313-cp313-macosx_11_0_arm64.whl (284 kB)
# Using cached safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl (418 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached torch-2.7.0-cp313-none-macosx_11_0_arm64.whl (68.6 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached typing_extensions-4.13.2-py3-none-any.whl (45 kB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached MarkupSafe-3.0.2-cp313-cp313-macosx_11_0_arm64.whl (12 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached pillow-11.2.1-cp313-cp313-macosx_11_0_arm64.whl (3.0 MB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.2-cp313-cp313-macosx_10_13_universal2.whl (199 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached urllib3-2.4.0-py3-none-any.whl (128 kB)
# Using cached certifi-2025.4.26-py3-none-any.whl (159 kB)
# Downloading setuptools-80.9.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.8 MB/s eta 0:00:00
# Installing collected packages: mpmath, urllib3, typing_extensions, tqdm, threadpoolctl, sympy, setuptools, safetensors, regex, pyyaml, Pillow, numpy, networkx, mdurl, MarkupSafe, joblib, idna, hf-xet, fsspec, filelock, charset-normalizer, certifi, scipy, requests, markdown-it-py, jinja2, torch, scikit-learn, rich, huggingface-hub, tokenizers, transformers, sentence-transformers, keybert
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34/34 [keybert]3/34 [keybert]-transformers]
# Successfully installed MarkupSafe-3.0.2 Pillow-11.2.1 certifi-2025.4.26 charset-normalizer-3.4.2 filelock-3.18.0 fsspec-2025.5.1 hf-xet-1.1.2 huggingface-hub-0.32.2 idna-3.10 jinja2-3.1.6 joblib-1.5.1 keybert-0.9.0 markdown-it-py-3.0.0 mdurl-0.1.2 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.6 pyyaml-6.0.2 regex-2024.11.6 requests-2.32.3 rich-14.0.0 safetensors-0.5.3 scikit-learn-1.6.1 scipy-1.15.3 sentence-transformers-4.1.0 setuptools-80.9.0 sympy-1.14.0 threadpoolctl-3.6.0 tokenizers-0.21.1 torch-2.7.0 tqdm-4.67.1 transformers-4.52.3 typing_extensions-4.13.2 urllib3-2.4.0
